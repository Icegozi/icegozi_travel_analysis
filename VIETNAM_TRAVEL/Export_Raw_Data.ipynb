# %% [markdown]
# # Export dữ liệu thô Vietnam.travel
#
# Chỉ thu thập nội dung công khai khi `robots.txt` cho phép.

# %%
import sys
from pathlib import Path

project_dir = Path.cwd()
if not (project_dir / 'crawl_vietnam_travel.py').exists():
    project_dir = project_dir / 'VIETNAM_TRAVEL'
sys.path.insert(0, str(project_dir))

import crawl_vietnam_travel

# %%
# Cấu hình lấy từ biến môi trường hoặc tệp .env khi chạy run_all.sh.
crawl_vietnam_travel.crawl()
